# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (2.5.1)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx) (4.4.2)

# %%
import networkx as nx

# %%
#https://github.com/ahmed-gharib89/Discrete-Math-and-Analyzing-Social-Graphs/blob/master/Final%20Quiz.ipynb

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
https://learn.datacamp.com/courses/introduction-to-network-analysis-in-python
https://learn.datacamp.com/courses/intermediate-network-analysis-in-python

# %%
# !wget -O facebook_combined.txt https://www.dropbox.com/s/efj6c78c4e4lknz/facebook_combined.txt?dl=0
# Out:
# --2021-06-05 06:22:08--  https://www.dropbox.com/s/efj6c78c4e4lknz/facebook_combined.txt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/efj6c78c4e4lknz/facebook_combined.txt [following]
# --2021-06-05 06:22:09--  https://www.dropbox.com/s/raw/efj6c78c4e4lknz/facebook_combined.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc161e53a0688227105f412d1e37.dl.dropboxusercontent.com/cd/0/inline/BP1hBhl_7g1XI2BFZ66m4fOsQQXs64jR_0alLevbqyGskOPCypy6MwT_outsKhnu46tEn9h_UeixbUIaHkm9w3s3j9GM6EyThpHdJYqL13OHkwovFBD3Cju_0DfO1zLu3PnRoVk12EeYMINW2Wf_8XSp/file# [following]
# --2021-06-05 06:22:09--  https://uc161e53a0688227105f412d1e37.dl.dropboxusercontent.com/cd/0/inline/BP1hBhl_7g1XI2BFZ66m4fOsQQXs64jR_0alLevbqyGskOPCypy6MwT_outsKhnu46tEn9h_UeixbUIaHkm9w3s3j9GM6EyThpHdJYqL13OHkwovFBD3Cju_0DfO1zLu3PnRoVk12EeYMINW2Wf_8XSp/file
# Resolving uc161e53a0688227105f412d1e37.dl.dropboxusercontent.com (uc161e53a0688227105f412d1e37.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc161e53a0688227105f412d1e37.dl.dropboxusercontent.com (uc161e53a0688227105f412d1e37.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 854362 (834K) [text/plain]
# Saving to: ‘facebook_combined.txt’
#
# facebook_combined.t 100%[===================>] 834.34K  --.-KB/s    in 0.1s
#
# 2021-06-05 06:22:09 (7.60 MB/s) - ‘facebook_combined.txt’ saved [854362/854362]

# %%
import pandas as pd 

fb  = pd.read_csv('facebook_combined.txt')

# %%
fb.head()
# Out:
#    0 1
# 0  0 2
# 1  0 3
# 2  0 4
# 3  0 5
# 4  0 6

# %%
import networkx as nx;
from random import random;

# Read data from the dataset, and create graph G_fb
G_fb = nx.read_edgelist("facebook_combined.txt", create_using = nx.Graph(), nodetype=int);

# Show the number of edges in G_fb
print("edges = " + str(G_fb.number_of_edges()));

# Show number of nodes in G_fb
print("nodes = " + str(G_fb.number_of_nodes()));

# TASK1. Now your task is to compute the probability whether there is an edge between two vertices.
edge_probab = G_fb.number_of_edges() / ((G_fb.number_of_nodes() * (G_fb.number_of_nodes()-1))/2)

# TASK2. Compute the ACC (average clustering coefficient) of G_fb
# (consult the NetworkX manual or the video lecture for the correct function which does it)
av_clust_coeff =  nx.average_clustering(G_fb)


# Now we have to generate a random graph. First we initialize it
#G_rand = nx.Graph();



# TASK3. generate edges in G_rand at random:
#for i in range(0,k) :
#    for j in range(0,i) : 
#        # Add an edge between vertices i and j, with probability edge_probab (as in G_fb)
#        G_rand.add_edge(i, j)
G_rand = nx.erdos_renyi_graph(G_fb.number_of_nodes(), edge_probab, seed=None, directed=False)

# Now we print out the number of edges and the ACC of the new graph
print("rgraph_edges = " + str(G_rand.number_of_edges()));

rgraph_acc  = nx.average_clustering(G_rand)

print("av_clust_coeff = " + str(av_clust_coeff));
print("rgraph_acc = " + str(rgraph_acc));
#get edge probability 
edge_probab
# Out:
# edges = 88234
# nodes = 4039
# rgraph_edges = 88177
# av_clust_coeff = 0.6055467186200876
# rgraph_acc = 0.01071617532106223
# 0.010819963503439287
