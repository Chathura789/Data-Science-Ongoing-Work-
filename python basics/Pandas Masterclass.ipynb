# %% [markdown]
# 01  Basics of Pandas

# %%
#full python tutorial 
#https://www.w3schools.com/python/python_operators.asp

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
##Code bit to mount drive
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Code Chunk to save a given subset to a specified path 

with open('gdrive/My Drive/Data Projects /Data/df_subset02.csv', 'w') as f:
    df_subset02.to_csv(f)

# %%
# Authenticate and create the PyDrive client.
# Notes : need to automate this step 
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link = 'https://drive.google.com/file/d/18oLmB7zhITuw6wd9kql53J_GaC299AwY/view?usp=sharing'
id = link.split("/")[5]
import pandas as pd 
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('df.csv')  
df = pd.read_csv('df.csv')

# %%
#.head Shows the head of the Data 
print(df.head())
# Out:
#   Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 0           WN          7/1/2015  ...                                    0 NaN
# 1           WN          7/1/2015  ...                                    0 NaN
# 2           WN          7/1/2015  ...                                    0 NaN
# 3           WN          7/1/2015  ...                                    0 NaN
# 4           WN          7/1/2015  ...                                    0 NaN
#
# [5 rows x 18 columns]

# %%
#Adding a number will only return a specifed row count 
print(df.head(3))
# Out:
#   Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 0           WN          7/1/2015  ...                                    0 NaN
# 1           WN          7/1/2015  ...                                    0 NaN
# 2           WN          7/1/2015  ...                                    0 NaN
#
# [3 rows x 18 columns]

# %%
#Same can be done for backend of Dataset 
print(df.tail(3))
# Out:
#      Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 1737           WN         7/31/2015  ...                                   36 NaN
# 1738           WN         7/31/2015  ...                                   48 NaN
# 1739           WN         7/31/2015  ...                                   58 NaN
#
# [3 rows x 18 columns]

# %%
# shape of the dataset 
df.shape
# Out:
# (1740, 18)

# %%
#Describe will give you summary statistics 

df.describe()
# Out:
#        Flight Number  ...  F18
# count    1740.000000  ...  0.0
# mean     1901.614368  ...  NaN
# std      1630.863317  ...  NaN
# min        22.000000  ...  NaN
# 25%       622.000000  ...  NaN
# 50%      1185.000000  ...  NaN
# 75%      3054.000000  ...  NaN
# max      5888.000000  ...  NaN
#
# [8 rows x 11 columns]

# %%
#df.values
#do for small data set & depict here

# %%
#Column Headers
df.columns
# Out:
# Index(['Carrier Code', 'Date (MM/DD/YYYY)', 'Flight Number', 'Tail Number',
#        'Destination Airport ', 'Scheduled Departure Time',
#        'Actual Departure Time', 'Scheduled Elapsed Time(Minutes)',
#        'Actual Elapsed Time(Minutes)', 'Departure Delay(Minutes)',
#        'Wheels-off Time', 'Taxi-out Time(Minutes)', 'DelayCarrier(Minutes)',
#        'DelayWeather(Minutes)', 'DelayNational Aviation System(Minutes)',
#        'DelaySecurity(Minutes)', 'DelayLate Aircraft Arrival(Minutes)', 'F18'],
#       dtype='object')

# %%
#Row count 
df.index
# Out:
# RangeIndex(start=0, stop=1740, step=1)

# %%
#Sort 
df_sort=df.sort_values(by='Date (MM/DD/YYYY)')

# %%
df_sort.head(3)
# Out:
#    Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 0            WN          7/1/2015  ...                                    0 NaN
# 31           WN          7/1/2015  ...                                    0 NaN
# 32           WN          7/1/2015  ...                                    0 NaN
#
# [3 rows x 18 columns]

# %%
#Sort Decending 
df_sort=df.sort_values(by='Date (MM/DD/YYYY)',ascending=False)

# %%
df_sort.head(2)
# Out:
#     Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 458           WN          7/9/2015  ...                                    0 NaN
# 471           WN          7/9/2015  ...                                    0 NaN
#
# [2 rows x 18 columns]

# %%
#Sort on multiple criteria 
df_sort=df.sort_values(['Date (MM/DD/YYYY)','Flight Number'])
df_sort.head(3)
# Out:
#   Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 0           WN          7/1/2015  ...                                    0 NaN
# 1           WN          7/1/2015  ...                                    0 NaN
# 2           WN          7/1/2015  ...                                    0 NaN
#
# [3 rows x 18 columns]

# %%
#Sort on multiple criteria  with differing ordering 
df_sort=df.sort_values(['Date (MM/DD/YYYY)','Flight Number'],ascending=[True,False])
df_sort.head(4)
# Out:
#    Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 57           WN          7/1/2015  ...                                   51 NaN
# 56           WN          7/1/2015  ...                                    0 NaN
# 55           WN          7/1/2015  ...                                    0 NaN
# 54           WN          7/1/2015  ...                                    0 NaN
#
# [4 rows x 18 columns]

# %%
#Subesetting Columns 
df_subset01=df[['Date (MM/DD/YYYY)','Flight Number']]
df_subset01.head(4)
# Out:
#   Date (MM/DD/YYYY)  Flight Number
# 0          7/1/2015            103
# 1          7/1/2015            144
# 2          7/1/2015            178
# 3          7/1/2015            232

# %%
#Convertion to Date 
#Auto format detection & parsing 
df['Date (MM/DD/YYYY)']= pd.to_datetime(df['Date (MM/DD/YYYY)'])

# %%
#Proof of type Convertion 
print (df.dtypes)
# Out:
# Carrier Code                                      object
# Date (MM/DD/YYYY)                         datetime64[ns]
# Flight Number                                      int64
# Tail Number                                       object
# Destination Airport                               object
# Scheduled Departure Time                          object
# Actual Departure Time                             object
# Scheduled Elapsed Time(Minutes)                    int64
# Actual Elapsed Time(Minutes)                       int64
# Departure Delay(Minutes)                           int64
# Wheels-off Time                                   object
# Taxi-out Time(Minutes)                             int64
# DelayCarrier(Minutes)                              int64
# DelayWeather(Minutes)                              int64
# DelayNational Aviation System(Minutes)             int64
# DelaySecurity(Minutes)                             int64
# ...

# %%
#Subetting Based on a logic 
df_subset02=df[df['Date (MM/DD/YYYY)']>'7/20/2015']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-24430ee513f0> in <module>()
#       1 #Subetting Based on a logic
# ----> 2 df_subset02=df[df['Date (MM/DD/YYYY)']>'7/20/2015']
#
# NameError: name 'df' is not defined

# %%
print(df_subset02.head(3))
# Out:
#      Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 1113           WN        2015-07-21  ...                                    0 NaN
# 1114           WN        2015-07-21  ...                                    0 NaN
# 1115           WN        2015-07-21  ...                                    0 NaN
#
# [3 rows x 18 columns]

# %%
#Subsetting based on multiple criteria 
df_subset03=df[['Date (MM/DD/YYYY)','Flight Number']]

# %%
#Add Calculated column to Dataframe done !!!!!
df['LengthofTail']=df['Tail Number'].str.len()

# %%
#check
df.head(2)
# Out:
#   Carrier Code Date (MM/DD/YYYY)  ...  F18 LengthofTail
# 0           WN        2015-07-01  ...  NaN            6
# 1           WN        2015-07-01  ...  NaN            6
#
# [2 rows x 19 columns]

# %%
#Subset Based on Multi conditions and operator 
df_subset03=df[(df['Date (MM/DD/YYYY)']>'7/20/2015') & (df['Carrier Code']=='WN')]
#

# %%
df_subset03.shape
# Out:
# (627, 19)

# %%
df_subset03.head(2)
# Out:
#      Carrier Code Date (MM/DD/YYYY)  ...  F18 LengthofTail
# 1113           WN        2015-07-21  ...  NaN            6
# 1114           WN        2015-07-21  ...  NaN            6
#
# [2 rows x 19 columns]

# %%
#Subset Based on Multi conditions or operator 
df_subset04=df[(df['Date (MM/DD/YYYY)']>'7/20/2015') | (df['Carrier Code']=='WN')]

# %%
df_subset04.tail(2)
# Out:
#      Carrier Code Date (MM/DD/YYYY)  ...  F18 LengthofTail
# 1738           WN        2015-07-31  ...  NaN            6
# 1739           WN        2015-07-31  ...  NaN            6
#
# [2 rows x 19 columns]

# %%
df_subset04.shape
# Out:
# (1740, 19)

# %%
#.isin Operator 
k=df['Tail Number'].isin(['N8649A','N8611F'])

# %%
df[k].shape
# Out:
# (11, 19)

# %%
#Quickly get Column Names 
cols = list(df.columns.values)

# %%
cols
# Out:
# ['Carrier Code',
#  'Date (MM/DD/YYYY)',
#  'Flight Number',
#  'Tail Number',
#  'Destination Airport ',
#  'Scheduled Departure Time',
#  'Actual Departure Time',
#  'Scheduled Elapsed Time(Minutes)',
#  'Actual Elapsed Time(Minutes)',
#  'Departure Delay(Minutes)',
#  'Wheels-off Time',
#  'Taxi-out Time(Minutes)',
#  'DelayCarrier(Minutes)',
#  'DelayWeather(Minutes)',
#  'DelayNational Aviation System(Minutes)',
#  'DelaySecurity(Minutes)',
#  'DelayLate Aircraft Arrival(Minutes)',
#  'F18',
#  'LengthofTail']

# %%
#Drop a column 
### Read below & learn how to drop "Nan" values 
#https://www.datacamp.com/community/tutorials/pandas-drop-column?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=332602034361&utm_targetid=dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=1009919&gclid=Cj0KCQjw8rT8BRCbARIsALWiOvSENyeNfG5_37c50KvQq_yrd8cEp5qiDcMkosmxhPop6XkMHhLV-ToaAsZKEALw_wcB
del df['F18']

# %%
df.shape
# Out:
# (1740, 18)

# %%
#Rename a column 
#https://cmdlinetips.com/category/python/
dftest = pd.DataFrame({'$a':[1,2], '$b': [10,20]})

# %%
#Before 
dftest.head()
# Out:
#    $a  $b
# 0   1  10
# 1   2  20

# %%
dftest.columns = ['a', 'b']

# %%
#After 
dftest.head()
# Out:
#    a   b
# 0  1  10
# 1  2  20

# %%
#Rearrange column headers 
#https://stackoverflow.com/questions/12329853/how-to-rearrange-pandas-column-sequence/23741704
dftest02 =pd.DataFrame({'a':[1,2,3,4],'b':[2,4,6,8]})
dftest02['x']=dftest02.a + dftest02.b
dftest02['y']=dftest02.a - dftest02.b

# %%
dftest02
# Out:
#    a  b   x  y
# 0  1  2   3 -1
# 1  2  4   6 -2
# 2  3  6   9 -3
# 3  4  8  12 -4

# %%
column_titles = ['x','y','a','b']

dftest02.reindex(columns=column_titles)
# Out:
#     x  y  a  b
# 0   3 -1  1  2
# 1   6 -2  2  4
# 2   9 -3  3  6
# 3  12 -4  4  8

# %% [markdown]
# # 02 Aggregating Data

# %%
link='https://drive.google.com/file/d/1NMVHYtu7HTBE0-jokUYofL4G7hPM5lgE/view?usp=sharing'

# %%
id = link.split("/")[5]

import pandas as pd 
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('sales_subset.csv')  
sales = pd.read_csv('sales_subset.csv')

# %%
sales.head(2)
# Out:
#    Unnamed: 0  store type  ...  temperature_c fuel_price_usd_per_l  unemployment
# 0           0      1    A  ...       5.727778             0.679451         8.106
# 1           1      1    A  ...       8.055556             0.693452         8.106
#
# [2 rows x 10 columns]

# %%
sales.mean()
# Out:
# Unnamed: 0               5386.500000
# store                      15.441897
# department                 45.218118
# weekly_sales            23843.950149
# is_holiday                  0.003898
# temperature_c              15.731978
# fuel_price_usd_per_l        0.749746
# unemployment                8.082009
# dtype: float64

# %%
sales['weekly_sales'].mean()
# Out:
# 23843.950148505668

# %%
#Similaly other stats are also available

# %% [markdown]
# ![image_2020-10-19_221407.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-19_221514.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-19_221558.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-19_221623.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-19_221703.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-19_221735.png](data:image/png;base64,...)

# %%
#.cummin() | .cummax() | .cumprod() exsists

# %%
# Print the head of the sales DataFrame
print(sales.head())

# Print the info about the sales DataFrame
print(sales.info())

# Print the mean of weekly_sales
print(sales["weekly_sales"].mean())

# Print the median of weekly_sales
print(sales["weekly_sales"].median())
# Out:
#    Unnamed: 0  store type  ...  temperature_c fuel_price_usd_per_l  unemployment
# 0           0      1    A  ...       5.727778             0.679451         8.106
# 1           1      1    A  ...       8.055556             0.693452         8.106
# 2           2      1    A  ...      16.816667             0.718284         7.808
# 3           3      1    A  ...      22.527778             0.748928         7.808
# 4           4      1    A  ...      27.050000             0.714586         7.808
#
# [5 rows x 10 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10774 non-null  int64
#  1   store                 10774 non-null  int64
#  2   type                  10774 non-null  object
#  3   department            10774 non-null  int64
#  4   date                  10774 non-null  object
# ...

# %%
# Print the maximum of the date column
print(sales["date"].max())

# Print the minimum of the date column
print(sales["date"].min())
# Out:
# 2012-10-26
# 2010-02-05

# %%
# A custom IQR function
def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)

# Update to print IQR of temperature_c, fuel_price_usd_per_l, & unemployment
print(sales[["temperature_c", 'fuel_price_usd_per_l','unemployment']].agg(iqr))
# Out:
# temperature_c           16.583333
# fuel_price_usd_per_l     0.073176
# unemployment             0.565000
# dtype: float64

# %%
# Import NumPy and create custom IQR function
import numpy as np
def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)

# Update to print IQR and median of temperature_c, fuel_price_usd_per_l, & unemployment
print(sales[["temperature_c", "fuel_price_usd_per_l", "unemployment"]].agg([iqr,np.median]))
# Out:
#         temperature_c  fuel_price_usd_per_l  unemployment
# iqr         16.583333              0.073176         0.565
# median      16.966667              0.743381         8.099

# %%
sales_1_1=sales[(sales['store']==1) & (sales['department']==1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-062c4efe11d1> in <module>()
# ----> 1 sales_1_1=sales[(sales['store']==1) & (sales['department']==1)]
#
# NameError: name 'sales' is not defined

# %%
# Sort sales_1_1 by date
sales_1_1 = sales_1_1.sort_values("date")

# Get the cumulative sum of weekly_sales, add as cum_weekly_sales col
sales_1_1["cum_weekly_sales"] = sales_1_1["weekly_sales"].cumsum()

# Get the cumulative max of weekly_sales, add as cum_max_sales col
sales_1_1["cum_max_sales"] = sales_1_1["weekly_sales"].cummax()

# See the columns you calculated
print(sales_1_1[["date", "weekly_sales", "cum_weekly_sales", "cum_max_sales"]])
# Out:
#           date  weekly_sales  cum_weekly_sales  cum_max_sales
# 0   2010-02-05      24924.50          24924.50       24924.50
# 1   2010-03-05      21827.90          46752.40       24924.50
# 2   2010-04-02      57258.43         104010.83       57258.43
# 3   2010-05-07      17413.94         121424.77       57258.43
# 4   2010-06-04      17558.09         138982.86       57258.43
# 5   2010-07-02      16333.14         155316.00       57258.43
# 6   2010-08-06      17508.41         172824.41       57258.43
# 7   2010-09-03      16241.78         189066.19       57258.43
# 8   2010-10-01      20094.19         209160.38       57258.43
# 9   2010-11-05      34238.88         243399.26       57258.43
# 10  2010-12-03      22517.56         265916.82       57258.43
# 11  2011-01-07      15984.24         281901.06       57258.43

# %%
#Counting WO Duplicates 1st example doesnt work since their are two dogs named max

# %% [markdown]
# ![image_2020-10-19_223950.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-19_224052.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-19_224217.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-19_224248.png](data:image/png;base64,...)

# %%
# Drop duplicate store/type combinations
store_types = sales.drop_duplicates(subset=["store", "type"])
print(store_types.head())

# Drop duplicate store/department combinations
store_depts = sales.drop_duplicates(subset=["store", "department"])
print(store_depts.head())

# Subset the rows where is_holiday is True and drop duplicate dates
holiday_dates = sales[sales["is_holiday"]].drop_duplicates(subset="date")

# Print date col of holiday_dates
print(holiday_dates["date"])
# Out:
#       Unnamed: 0  store type  ...  temperature_c fuel_price_usd_per_l  unemployment
# 0              0      1    A  ...       5.727778             0.679451         8.106
# 901          901      2    A  ...       4.550000             0.679451         8.324
# 1798        1798      4    A  ...       6.533333             0.686319         8.623
# 2699        2699      6    A  ...       4.683333             0.679451         7.259
# 3593        3593     10    B  ...      12.411111             0.782478         9.765
#
# [5 rows x 10 columns]
#     Unnamed: 0  store type  ...  temperature_c fuel_price_usd_per_l  unemployment
# 0            0      1    A  ...       5.727778             0.679451         8.106
# 12          12      1    A  ...       5.727778             0.679451         8.106
# 24          24      1    A  ...       5.727778             0.679451         8.106
# 36          36      1    A  ...       5.727778             0.679451         8.106
# ...

# %%
# Count the number of stores of each type
store_counts = store_types["type"].value_counts()
print(store_counts)

# Get the proportion of stores of each type
store_props = store_types["type"].value_counts(normalize=True)
print(store_props)

# Count the number of each department number and sort
dept_counts_sorted = store_depts["department"].value_counts(sort=True)
print(dept_counts_sorted)
# Out:
# A    11
# B     1
# Name: type, dtype: int64
# A    0.916667
# B    0.083333
# Name: type, dtype: float64
# 41    12
# 30    12
# 23    12
# 24    12
# 25    12
#       ..
# 37    10
# 48     8
# 50     6
# 39     4
# 43     2
# Name: department, Length: 80, dtype: int64

# %% [markdown]
# ![image_2020-10-20_004731.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-20_005003.png](data:image/png;base64,...)

# %%
# Calc total weekly sales
sales_all = sales["weekly_sales"].sum()

# Subset for type A stores, calc total weekly sales
sales_A = sales[sales["type"] == "A"]["weekly_sales"].sum()

# Subset for type B stores, calc total weekly sales
sales_B = sales[sales["type"] == "B"]["weekly_sales"].sum()

# Subset for type C stores, calc total weekly sales
sales_C = sales[sales["type"] == "C"]["weekly_sales"].sum()

# Get proportion for each type
sales_propn_by_type = [sales_A, sales_B, sales_C] / sales_all
print(sales_propn_by_type)
# Out:
# [0.9097747 0.0902253 0.       ]

# %%
# Group by type; calc total weekly sales
sales_by_type = sales.groupby("type")["weekly_sales"].sum()

# Get proportion for each type
sales_propn_by_type = sales_by_type / sum(sales_by_type)
print(sales_propn_by_type)
# Out:
# type
# A    0.909775
# B    0.090225
# Name: weekly_sales, dtype: float64

# %%
# From previous step
sales_by_type = sales.groupby("type")["weekly_sales"].sum()

# Group by type and is_holiday; calc total weekly sales
sales_by_type_is_holiday = sales.groupby(["type", "is_holiday"])["weekly_sales"].sum()
print(sales_by_type_is_holiday)
# Out:
# type  is_holiday
# A     False         2.336927e+08
#       True          2.360181e+04
# B     False         2.317678e+07
#       True          1.621410e+03
# Name: weekly_sales, dtype: float64

# %%
import numpy as np
# For each store type, aggregate weekly_sales: get min, max, mean, and median
sales_stats = sales.groupby("type")["weekly_sales"].agg([np.min, np.max, np.mean, np.median])

# Print sales_stats
print(sales_stats)

# For each store type, aggregate unemployment and fuel_price_usd_per_l: get min, max, mean, and median
unemp_fuel_stats = sales.groupby("type")[["unemployment", "fuel_price_usd_per_l"]].agg([np.min, np.max, np.mean, np.median])

# Print unemp_fuel_stats
print(unemp_fuel_stats)
# Out:
#         amin       amax          mean    median
# type
# A    -1098.0  293966.05  23674.667242  11943.92
# B     -798.0  232558.51  25696.678370  13336.08
#      unemployment                   ... fuel_price_usd_per_l
#              amin   amax      mean  ...                 amax      mean    median
# type                                ...
# A           3.879  8.992  7.972611  ...             1.107410  0.744619  0.735455
# B           7.170  9.765  9.279323  ...             1.107674  0.805858  0.803348
#
# [2 rows x 8 columns]

# %% [markdown]
# ##Pivot Tables

# %% [markdown]
# ![image_2020-10-20_010020.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-20_010052.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-20_010124.png](data:image/png;base64,...)

# %%
# Pivot for mean weekly_sales by store type and holiday 
mean_sales_by_type_holiday = sales.pivot_table(values="weekly_sales", index="type", columns="is_holiday")

# Print mean_sales_by_type_holiday
print(mean_sales_by_type_holiday)
# Out:
# is_holiday         False      True
# type
# A           23768.583523  590.04525
# B           25751.980533  810.70500

# %%
# Print the mean weekly_sales by department and type; fill missing values with 0s; sum all rows and cols
print(sales.pivot_table(values="weekly_sales", index="department", columns="type", fill_value=0, margins=True))
# Out:
# type                   A              B           All
# department
# 1           30961.725379   44050.626667  32052.467153
# 2           67600.158788  112958.526667  71380.022778
# 3           17160.002955   30580.655000  18278.390625
# 4           44285.399091   51219.654167  44863.253681
# 5           34821.011364   63236.875000  37189.000000
# ...                  ...            ...           ...
# 96          21367.042857    9528.538333  20337.607681
# 97          28471.266970    5828.873333  26584.400833
# 98          12875.423182     217.428333  11820.590278
# 99            379.123659       0.000000    379.123659
# All         23674.667242   25696.678370  23843.950149
#
# [81 rows x 3 columns]

# %% [markdown]
# #Slicing & Indexing

# %%
link='https://drive.google.com/file/d/16Zmjw16c74pS3Es1RxBNOMpwTx_UJnQE/view?usp=sharing'
id = link.split("/")[5]

import pandas as pd 
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('temperatures.csv')  
temperatures = pd.read_csv('temperatures.csv')

# %%
temperatures.head(2)
# Out:
#    Unnamed: 0        date     city        country  avg_temp_c
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685

# %%
temperatures.shape
# Out:
# (16500, 5)

# %%
# Look at temperatures
print(temperatures)

# Index temperatures by city
temperatures_ind = temperatures.set_index("city")

# Look at temperatures_ind
print(temperatures_ind)

# Reset the index, keeping its contents
print(temperatures_ind.reset_index())
# Out:
#        Unnamed: 0        date     city        country  avg_temp_c
# 0               0  2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1               1  2000-02-01  Abidjan  Côte D'Ivoire      27.685
# 2               2  2000-03-01  Abidjan  Côte D'Ivoire      29.061
# 3               3  2000-04-01  Abidjan  Côte D'Ivoire      28.162
# 4               4  2000-05-01  Abidjan  Côte D'Ivoire      27.547
# ...           ...         ...      ...            ...         ...
# 16495       16495  2013-05-01     Xian          China      18.979
# 16496       16496  2013-06-01     Xian          China      23.522
# 16497       16497  2013-07-01     Xian          China      25.251
# 16498       16498  2013-08-01     Xian          China      24.528
# 16499       16499  2013-09-01     Xian          China         NaN
#
# [16500 rows x 5 columns]
#          Unnamed: 0        date        country  avg_temp_c
# city
# Abidjan           0  2000-01-01  Côte D'Ivoire      27.293
# ...

# %%
# Make a list of cities to subset on
cities = ["Moscow", "Saint Petersburg"]

# Subset temperatures using square brackets
print(temperatures[temperatures["city"].isin(cities)])

# Subset temperatures_ind using .loc[]
print(temperatures_ind.loc[cities])
# Out:
#        Unnamed: 0        date              city country  avg_temp_c
# 10725       10725  2000-01-01            Moscow  Russia      -7.313
# 10726       10726  2000-02-01            Moscow  Russia      -3.551
# 10727       10727  2000-03-01            Moscow  Russia      -1.661
# 10728       10728  2000-04-01            Moscow  Russia      10.096
# 10729       10729  2000-05-01            Moscow  Russia      10.357
# ...           ...         ...               ...     ...         ...
# 13360       13360  2013-05-01  Saint Petersburg  Russia      12.355
# 13361       13361  2013-06-01  Saint Petersburg  Russia      17.185
# 13362       13362  2013-07-01  Saint Petersburg  Russia      17.234
# 13363       13363  2013-08-01  Saint Petersburg  Russia      17.153
# 13364       13364  2013-09-01  Saint Petersburg  Russia         NaN
#
# [330 rows x 5 columns]
#                   Unnamed: 0        date country  avg_temp_c
# city
# Moscow                 10725  2000-01-01  Russia      -7.313
# ...

# %%
#Setting Multi level indexes 
# Index temperatures by country & city
temperatures_ind = temperatures.set_index(["country", "city"])

# List of tuples: Brazil, Rio De Janeiro & Pakistan, Lahore
rows_to_keep = [("Brazil", "Rio De Janeiro"), ("Pakistan", "Lahore")]

# Subset for rows to keep
print(temperatures_ind.loc[rows_to_keep])
# Out:
#                          Unnamed: 0        date  avg_temp_c
# country  city
# Brazil   Rio De Janeiro       12540  2000-01-01      25.974
#          Rio De Janeiro       12541  2000-02-01      26.699
#          Rio De Janeiro       12542  2000-03-01      26.270
#          Rio De Janeiro       12543  2000-04-01      25.750
#          Rio De Janeiro       12544  2000-05-01      24.356
# ...                             ...         ...         ...
# Pakistan Lahore                8575  2013-05-01      33.457
#          Lahore                8576  2013-06-01      34.456
#          Lahore                8577  2013-07-01      33.279
#          Lahore                8578  2013-08-01      31.511
#          Lahore                8579  2013-09-01         NaN
#
# [330 rows x 3 columns]

# %%
#Sort by Index values 
# Sort temperatures_ind by index values
print(temperatures_ind.sort_index())

# Sort temperatures_ind by index values at the city level
print(temperatures_ind.sort_index(level="city"))

# Sort temperatures_ind by country then descending city
print(temperatures_ind.sort_index(level=["country", "city"], ascending = [True, False]))
# Out:
#                     Unnamed: 0        date  avg_temp_c
# country     city
# Afghanistan Kabul         7260  2000-01-01       3.326
#             Kabul         7261  2000-02-01       3.454
#             Kabul         7262  2000-03-01       9.612
#             Kabul         7263  2000-04-01      17.925
#             Kabul         7264  2000-05-01      24.658
# ...                        ...         ...         ...
# Zimbabwe    Harare        5605  2013-05-01      18.298
#             Harare        5606  2013-06-01      17.020
#             Harare        5607  2013-07-01      16.299
#             Harare        5608  2013-08-01      19.232
#             Harare        5609  2013-09-01         NaN
#
# [16500 rows x 3 columns]
#                        Unnamed: 0        date  avg_temp_c
# country       city
# Côte D'Ivoire Abidjan           0  2000-01-01      27.293
#               Abidjan           1  2000-02-01      27.685
#               Abidjan           2  2000-03-01      29.061
# ...

# %% [markdown]
# #Slicing with loc & iloc

# %% [markdown]
# ![image_2020-10-20_013137.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-20_013208.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-20_013357.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-20_013436.png](data:image/png;base64,...)

# %%
# Sort the index of temperatures_ind
temperatures_srt = temperatures_ind.sort_index()

# Subset rows from Pakistan to Russia
print(temperatures_srt.loc["Pakistan":"Russia"])

# Try to subset rows from Lahore to Moscow
print(temperatures_srt.loc["Lahore":"Moscow"])

# Subset rows from Pakistan, Lahore to Russia, Moscow
print(temperatures_srt.loc[("Pakistan", "Lahore"):("Russia", "Moscow")])
# Out:
#                            Unnamed: 0        date  avg_temp_c
# country  city
# Pakistan Faisalabad              4785  2000-01-01      12.792
#          Faisalabad              4786  2000-02-01      14.339
#          Faisalabad              4787  2000-03-01      20.309
#          Faisalabad              4788  2000-04-01      29.072
#          Faisalabad              4789  2000-05-01      34.845
# ...                               ...         ...         ...
# Russia   Saint Petersburg       13360  2013-05-01      12.355
#          Saint Petersburg       13361  2013-06-01      17.185
#          Saint Petersburg       13362  2013-07-01      17.234
#          Saint Petersburg       13363  2013-08-01      17.153
#          Saint Petersburg       13364  2013-09-01         NaN
#
# [1155 rows x 3 columns]
#                     Unnamed: 0        date  avg_temp_c
# country city
# Mexico  Mexico           10230  2000-01-01      12.694
#         Mexico           10231  2000-02-01      14.677
# ...

# %% [markdown]
# Create a vizualize Data Frames

# %%
import matplotlib.pyplot as plt

# %%
import pickle

# %%
link='https://drive.google.com/file/d/1Ts3NHHC-7MOTYMeIZKAqbOmj1ijpvNOx/view?usp=sharing'
id = link.split("/")[5]

import pandas as pd 
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('avoplotto.pkl')  
temperatures = pd.read_csv('temperatures.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-04842e6903f6> in <module>()
#       3
#       4 import pandas as pd
# ----> 5 downloaded = drive.CreateFile({'id':id})
#       6 downloaded.GetContentFile('avoplotto.pkl')
#       7 temperatures = pd.read_csv('temperatures.csv')
#
# AttributeError: module 'google.colab.drive' has no attribute 'CreateFile'

# %%
with open('avoplotto.pkl', 'rb') as f:
    avocados = pickle.load(f)

# %%
avocados.head(2)
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76

# %%
avocados.shape
# Out:
# (1014, 6)

# %%
avocados.columns
# Out:
# Index(['date', 'type', 'year', 'avg_price', 'size', 'nb_sold'], dtype='object')

# %%
# Get the total number of avocados sold of each size
nb_sold_by_size = avocados.groupby("size")["nb_sold"].sum()

# Create a bar plot of the number of avocados sold by size
nb_sold_by_size.plot(kind="bar")

# Show the plot
plt.show()

# %%
#Changes in Sales over time 
# Get the total number of avocados sold on each date
nb_sold_by_date = avocados.groupby("date")["nb_sold"].sum()

# Create a line plot of the number of avocados sold by date
nb_sold_by_date.plot(kind="line")

# Show the plot
plt.show()

# %%
# Scatter plot of nb_sold vs avg_price with title
avocados.plot(x="nb_sold", y="avg_price", kind="scatter", title="Number of avocados sold vs. average price")

# Show the plot
plt.show()

# %%
# Modify bins to 20
avocados[avocados["type"] == "conventional"]["avg_price"].hist(alpha=0.5, bins=20)
# Modify bins to 20
avocados[avocados["type"] == "organic"]["avg_price"].hist(alpha=0.5, bins=20)
# Add a legend
plt.legend(["conventional", "organic"])
# Show the plot
plt.show()

# %% [markdown]
# Dealing with missing Values

# %%
#Check if any values are Nan
avocados.isna().any()
# Out:
# date         False
# type         False
# year         False
# avg_price    False
# size         False
# nb_sold      False
# dtype: bool

# %%
#Count the no of Nan
avocados.isna().sum()
# Out:
# date         0
# type         0
# year         0
# avg_price    0
# size         0
# nb_sold      0
# dtype: int64

# %%
#Plot the Missing values 
df.isna().sum().plot(kind='bar')
plt.show()

# %%
#Remove data missing rows 
dfnaremoved=df.dropna()
dfnaremoved.head(1)
#Since f18 entire col is Nan no data is left
# Out:
# Empty DataFrame
# Columns: [Carrier Code, Date (MM/DD/YYYY), Flight Number, Tail Number, Destination Airport , Scheduled Departure Time, Actual Departure Time, Scheduled Elapsed Time(Minutes), Actual Elapsed Time(Minutes), Departure Delay(Minutes), Wheels-off Time, Taxi-out Time(Minutes), DelayCarrier(Minutes), DelayWeather(Minutes), DelayNational Aviation System(Minutes), DelaySecurity(Minutes), DelayLate Aircraft Arrival(Minutes), F18]
# Index: []

# %%
dfnaremoved=df.fillna(1)
dfnaremoved.head(1)
# Out:
#   Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes)  F18
# 0           WN          7/1/2015  ...                                    0  1.0
#
# [1 rows x 18 columns]

# %% [markdown]
# ![image_2020-10-20_211049.png](data:image/png;base64,...)

# %% [markdown]
# Reading & Wiritng CSV'S

# %% [markdown]
# ![image_2020-10-20_211238.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2020-10-20_211546.png](data:image/png;base64,...)
