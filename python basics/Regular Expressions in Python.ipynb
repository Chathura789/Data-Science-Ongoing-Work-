# %%
movie ='oh my God! desserts I stressed was an ugly movie'

# %%
len(movie)
# Out:
# 48

# %%
# Get the word
movie_title = movie[11:30]

# %%
# Obtain the palindrome
palindrome = movie_title[::-1]

# %%
palindrome
# Out:
# 'desserts I stressed'

# %%
# Print the word if it's a palindrome
if movie_title == palindrome:
	print(movie_title
       )
# Out:
# desserts I stressed

# %%
#String operations 
my_string = 'tHis Is a niCe StriNg'

# %%
my_string.lower()
# Out:
# 'this is a nice string'

# %%
my_string.upper()
# Out:
# 'THIS IS A NICE STRING'

# %%
#string manipulation capitalize the first char 
my_string.capitalize()
# Out:
# 'This is a nice string'

# %%
my_string = 'This string will be split'

# %%
#splitting the strings 
# sep the separator used 
# maxsplit = max no of substrings used 
#normal split begins in the left 
my_string.split(sep=' ',maxsplit=2)
# Out:
# ['This', 'string', 'will be split']

# %%
#rsplit begins on the right 
my_string.rsplit(sep=" ",maxsplit=2)
# Out:
# ['This string will', 'be', 'split']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_string = "This string will be split\nin two"

# %%
my_string = "This string will be split\rin two"

# %%
my_string
# Out:
# 'This string will be split\rin two'

# %%
my_string.splitlines()
# Out:
# ['This string will be split', 'in two']

# %%
my_list =['this','would','be','a','single','line']

# %%
print(" ".join(my_list))
# Out:
# this would be a single line

# %%
my_string =" this string will be stripped\n"

# %%
my_string.strip()
# Out:
# 'this string will be stripped'

# %%
my_string.rstrip()
# Out:
# ' this string will be stripped'

# %%
my_string.lstrip()
# Out:
# 'this string will be stripped\n'

# %%
movie = '$I supposed that coming from MTV Films I should expect no less$'

# %%
# To remove a char of a string from the beginning and the end, use string.strip(char)
movie_no_sign= movie.strip('$')

# %%
# Split the string into substrings and print the result
movie_split = movie_no_sign.split()
print(movie_split)
# Out:
# ['I', 'supposed', 'that', 'coming', 'from', 'MTV', 'Films', 'I', 'should', 'expect', 'no', 'less']

# %%
#To select all the character of word except the last one, use word[:-1].
# Select root word and print the result
word_root = movie_split[1][:-1]
print(word_root)
# Out:
# suppose

# %%
movie ='the film,however,is all good<\\i>'

# %%
movie.strip('<\\i>')
# Out:
# 'the film,however,is all good'

# %%
# Remove tags happening at the end and print results
movie_tag = movie.rstrip("<\i>")
print(movie_tag)

# Split the string using commas and print results
movie_no_comma = movie_tag.split(",")
print(movie_no_comma)
# Out:
# the film,however,is all good
# ['the film', 'however', 'is all good']

# %%
# Split the string using commas and print results
movie_no_comma = movie_tag.split(",")
print(movie_no_comma)
# Out:
# ['the film', 'however', 'is all good']

# %%
# Join back together and print results
movie_join =" ".join(movie_no_comma)
print(movie_join)
# Out:
# the film however is all good

# %%
file = 'mtv films election, a high school comedy, is a current example\nfrom there, director steven spielberg wastes no time, taking us into the water on a midnight swim'

# %%
#split lines 
# Split string at line boundaries
file_split = file.splitlines()

# Print file_split
print(file_split)
# Out:
# ['mtv films election, a high school comedy, is a current example', 'from there, director steven spielberg wastes no time, taking us into the water on a midnight swim']

# %%
# Complete for-loop to split by commas
for substring in file_split:
    substring_split = substring.split(",")
    print(substring_split)
# Out:
# ['mtv films election', ' a high school comedy', ' is a current example']
# ['from there', ' director steven spielberg wastes no time', ' taking us into the water on a midnight swim']

# %% [markdown]
# #finding susbtrings
# ![image.png](data:image/png;base64,...)

# %%
my_string = "Where's Waldo"

# %%
my_string.find('Waldo')
#find method returns the lowest index in the string where it can find the substring, in this case, eight.
# Out:
# 8

# %%
my_string.find('Wenda') #in this case the substring is not there and returns -1
# Out:
# -1

# %%
my_string.find('Waldo',0,5) # waldo is not between char 0 and 5
# Out:
# -1

# %%
my_string1 = "Where's Waldo I want to find Waldo"

# %%
my_string1.count('Waldo')
# Out:
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget -O short_movies.csv https://www.dropbox.com/s/2uhm1fowcjdfuuj/short_movies.csv?dl=0
# Out:
# --2021-07-10 15:43:34--  https://www.dropbox.com/s/2uhm1fowcjdfuuj/short_movies.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/2uhm1fowcjdfuuj/short_movies.csv [following]
# --2021-07-10 15:43:34--  https://www.dropbox.com/s/raw/2uhm1fowcjdfuuj/short_movies.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uced682825a7ab1dffc825c8ed98.dl.dropboxusercontent.com/cd/0/inline/BSAxdhF76kaaSxM1bSPBLLYU3CbWqTtvQ7NCDplOnIBK5Fxx9USn1VW5Eylaz_v3dLX132EWEI2-qeL1v5PjF62HNIBKJiflxj4VUe_eG9e8gmfTXZeNrhf67HQyyI7SrDtcoKRvZK-NVQA8GXKVfVzH/file# [following]
# ...

# %%
import pandas as pd

# %%
movies01= pd.read_csv('short_movies.csv')

# %%
movies01.head()
# Out:
#    id    tag  ...                                               text  target
# 0   0  cv000  ...  films adapted from comic books have had plenty...     pos
# 1   0  cv000  ...  for starters , it was created by alan moore ( ...     pos
# 2   0  cv000  ...  to say moore and campbell thoroughly researche...     pos
# 3   0  cv000  ...  the book ( or " graphic novel , " if you will ...     pos
# 4   0  cv000  ...  in other words , don't dismiss this film becau...     pos
#
# [5 rows x 6 columns]

# %%
movies= movies01['text']

# %%
for movie in movies:
  	# If actor is not found between character 37 and 41 inclusive
    # Print word not found
    if movie.find("actor", 37, 42) == -1:
        print("Word not found")
    # Count occurrences and replace two with one
    elif movie.count("actor") == 2:  
        print(movie.replace("actor actor", "actor"))
    else:
        # Replace three occurrences with one
        print(movie.replace("actor actor actor", "actor"))

# %%
#find the index where money occurs between characters with index 12 and 50. If not found, it should raise an error.
for movie in movies:
  try:
    # Find the first occurrence of word
  	print(movie.index("money", 12, 51))
  except ValueError:
    print("substring not found")

# %%
# Replace negations 
movies_no_negation = movies.replace("isn't", "is")

# Replace important
movies_antonym = movies_no_negation.replace("important", "insignificant")

# Print out
print(movies_antonym)
# Out:
# 0        films adapted from comic books have had plenty...
# 1        for starters , it was created by alan moore ( ...
# 2        to say moore and campbell thoroughly researche...
# 3        the book ( or " graphic novel , " if you will ...
# 4        in other words , don't dismiss this film becau...
#                                ...
# 19995    wilder's script is stunning , as he carefully ...
# 19996    wilder manages to create scenes of utter hyste...
# 19997    wilder's is dead wrong when he says nobody's p...
# 19998                  nobody's perfect but billy wilder .
# 19999    a welcome cinematic trend over the past couple...
# Name: text, Length: 20000, dtype: object

# %%
type(movies_antonym)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #Unit 02
# Formatting strings

# %%
my_string = '{} rely on datasets {}'

# %%
method = 'supervised  algorithm'

# %%
condition = 'labeled'

# %%
print(my_string.format(method,condition))
# Out:
# supervised  algorithm rely on datasets labeled

# %%
#by including an index you can reorder placeholder values 
print("{1} has a friend called {2} and a brother called {0}".format("markus","amelia","victor"))
# Out:
# amelia has a friend called victor and a brother called markus

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
wikipedia_article = 'In computer science, artificial intelligence (AI), sometimes called machine intelligence, is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals.'

# %%
# Assign the substrings to the variables
first_pos = wikipedia_article[3:19].lower()

# %%
print(first_pos)
# Out:
# computer science

# %%
second_pos = wikipedia_article[21:44].lower()

# %%
print(second_pos)
# Out:
# artificial intelligence

# %%
my_list = []

# %%
# Define string with placeholders 
my_list.append("The tool {} is used in {}")

# Define string with rearranged placeholders
my_list.append("The tool {1} is used in {0}")

# Use format to print strings
for my_string in my_list:
  	print(my_string.format(first_pos, second_pos))
# Out:
# The tool computer science is used in artificial intelligence
# The tool artificial intelligence is used in computer science

# %%
#Calling by its name

# %% [markdown]
# #Isuras question check applicability

# %%
string = '2,34,67,34521,288,36'

# %%
re.findall(r"(\d+(?:,d+)*)", string)
# Out:
# ['2', '34', '67', '34521', '288', '36']
