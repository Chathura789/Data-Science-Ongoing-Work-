# %% [markdown]
# ### Welcome youngling to the python training wheels protocol
# Lets get you upto speed in python

# %%
#Mathematical Operators 
# Just testing division
print(5 / 8)

# Addition works too
print(7 + 10)


#subtractions 
print(10-7)


#Multiplications 

print(9*45)
# Out:
# 0.625
# 17
# 3
# 405

# %%
#Some more maths 
# Exponentiation
print(4 ** 2)

# Modulo
print(18 % 7)

# How much is your $100 worth after 7 years?
print(100*((1.1**7)))
# Out:
# 16
# 4
# 194.87171000000012

# %%
#Variable assignment can improve reprocebility

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
day_of_week= 5

# %%
type(day_of_week)
# Out:
# int

# %%
h = "Hello world"

# %%
type(h)
# Out:
# str

# %%
z1=True

# %%
type(z1)
# Out:
# bool

# %% [markdown]
# Lists
#
# ![image.png](data:image/png;base64,...)

# %%
#Subsetting Lists 
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# %%
print(areas[0])
print(areas[1])
print(areas[-1])
print(areas[5])
# Out:
# hallway
# 11.25
# 9.5
# 20.0

# %%
# Sum of kitchen and bedroom area: eat_sleep_area
eat_sleep_area = areas[3]+areas[7]

# Print the variable eat_sleep_area
print(eat_sleep_area)
# Out:
# 28.75

# %%
#Slicing 
# Use slicing to create downstairs
downstairs=areas[:6]

# Use slicing to create upstairs
upstairs=areas[6:]


# Print out downstairs and upstairs
print(downstairs)

print(upstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom', 9.5]

# %%
#Alternative Slicing 

# Alternative slicing to create downstairs
downstairs=areas[:6]

# Alternative slicing to create upstairs
upstairs=areas[6:]
print(upstairs)
# Out:
# ['bedroom', 10.75, 'bathroom', 9.5]

# %%
#Replace list elements 
# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Correct the bathroom area
areas[-1]=10.50
print(areas)
# Change "living room" to "chill zone"
areas[4]='chill zone'
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bedroom', 10.75, 'bathroom', 10.5]

# %%
#Extending Lists 
# Create the areas list and make some changes
areas = ["hallway", 11.25, "kitchen", 18.0, "chill zone", 20.0, 
         "bedroom", 10.75, "bathroom", 10.50]

# Add poolhouse data to areas, new list is areas_1
areas_1=areas+['poolhouse',24.5]

# Add garage data to areas_1, new list is areas_2
areas_2=areas_1+['garage',15.45]

# %%
print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5]

# %%
#Deleting List elements 
del(areas[-4:-2]) #upto and including -2 to -4 is gone 

print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bathroom', 10.5]

# %%
a = (2,56,89,101)
b = (2,5,6)
c = (2,5,89)

# %%
a,c,b = b,a,c

# %%
print(c)
# Out:
# (2, 56, 89, 101)

# %%
#Help with Functions
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(...)
#     round(number[, ndigits]) -> number
#
#     Round a number to a given precision in decimal digits (default 0 digits).
#     This returns an int when called with one argument, otherwise the
#     same type as the number. ndigits may be negative.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Numpy Basics 
https://jakevdp.github.io/PythonDataScienceHandbook/02.02-the-basics-of-numpy-arrays.html
https://www.youtube.com/watch?v=VtCZFlTbOek
https://www.youtube.com/watch?v=d6O_bXgnjb4
https://www.youtube.com/watch?v=GB9ByFAIAH4
https://towardsdatascience.com/numpy-essentials-for-data-science-25dc39fae39

# %% [markdown]
# ### Intermediate Python

# %% [markdown]
# ### PDF ALLIES
#
# ### https://drive.google.com/drive/folders/12v-hYdsYqQdb2ERhjOrMcEPbLhRW_R4W?usp=sharing

# %%
#Python Dictionaries 

# Definition of countries and capital
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

# From string in countries and capitals, create dictionary europe
europe={'spain':'madrid', 'france':'paris', 'germany': 'berlin', 'norway':'oslo'}

# Print europe
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo'}

# %%
   # Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# Print out the keys in europe
print(europe.keys())

# Print out value that belongs to key 'norway'
print (europe['norway'])
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])
# oslo

# %%
#Dictionary Manipulation 
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# Add italy to europe
europe['italy'] = 'rome'


# Print out italy in europe
print( 'italy' in europe)

# Add poland to europe
europe['poland'] = 'warsaw'

# Print europe
print(europe)
# Out:
# True
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
#update & drop items from Lists 
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn', 
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw', 
          'australia':'vienna' }

# Update capital of germany
europe['germany']='bonn'

# Remove australia
del(europe['australia'])

# Print europe
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
#Pandas dictionary to Dataframe 
import pandas as pd

# Build cars DataFrame
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
dict = { 'country':names, 'drives_right':dr, 'cars_per_cap':cpc }
cars = pd.DataFrame(dict)
print(cars)

# Definition of row_labels
row_labels = ['US', 'AUS', 'JAP', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index=row_labels

# Print cars again
print(cars)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JAP          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %%
#Dictionary to Data frame 02

import pandas as pd

# Build cars DataFrame
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
dict = { 'country':names, 'drives_right':dr, 'cars_per_cap':cpc }
cars = pd.DataFrame(dict)
print(cars)

# Definition of row_labels
row_labels = ['US', 'AUS', 'JAP', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index=row_labels

# Print cars again
print(cars)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JAP          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %%
# csv to df refer pandas masterclass

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
# Build cars DataFrame
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
dict = { 'country':names, 'drives_right':dr, 'cars_per_cap':cpc }
cars = pd.DataFrame(dict)
print(cars)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45

# %%
cars['country']
# Out:
# 0    United States
# 1        Australia
# 2            Japan
# 3            India
# 4           Russia
# 5          Morocco
# 6            Egypt
# Name: country, dtype: object

# %%
type(cars['country'])
# Out:
# pandas.core.series.Series

# %%
#think of the above as a one dimensional array 
#but what if you want keep the selection as a dataframe ??

# %%
type(cars[['country']])
# Out:
# pandas.core.frame.DataFrame

# %%
#Multiple Column Access 
cars[['country','cars_per_cap']]
# Out:
#          country  cars_per_cap
# 0  United States           809
# 1      Australia           731
# 2          Japan           588
# 3          India            18
# 4         Russia           200
# 5        Morocco            70
# 6          Egypt            45

# %%
type(cars[['country','cars_per_cap']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Definition of row_labels
row_labels = ['US', 'AUS', 'JAP', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index=row_labels

# %%
cars.loc["RU"]
# Out:
# country         Russia
# drives_right      True
# cars_per_cap       200
# Name: RU, dtype: object

# %%
# to get a dataframe 

cars.loc[['RU']]
# Out:
#    country  drives_right  cars_per_cap
# RU  Russia          True           200

# %%
#Select multiple row labels to a list to get multiple rows 

cars.loc[['RU','AUS','MOR']]
# Out:
#        country  drives_right  cars_per_cap
# RU      Russia          True           200
# AUS  Australia         False           731
# MOR    Morocco          True            70

# %%
#To select both rows & columns 
cars.loc[['RU','AUS','MOR'],['country','cars_per_cap']]
# Out:
#        country  cars_per_cap
# RU      Russia           200
# AUS  Australia           731
# MOR    Morocco            70

# %%
#To select all rows but only select columns 
cars.loc[:,['country','cars_per_cap']]
# Out:
#            country  cars_per_cap
# US   United States           809
# AUS      Australia           731
# JAP          Japan           588
# IN           India            18
# RU          Russia           200
# MOR        Morocco            70
# EG           Egypt            45

# %%
#To do the same thing with iloc  
cars.iloc[:,[0,1]]
# Out:
#            country  drives_right
# US   United States          True
# AUS      Australia         False
# JAP          Japan         False
# IN           India         False
# RU          Russia          True
# MOR        Morocco          True
# EG           Egypt          True

# %%
# some more examples 

cars.loc['IN', 'cars_per_cap']
cars.iloc[3, 0]

cars.loc[['IN', 'RU'], 'cars_per_cap']
cars.iloc[[3, 4], 0]

cars.loc[['IN', 'RU'], ['cars_per_cap', 'country']]
cars.iloc[[3, 4], [0, 1]]
# Out:
#    country  drives_right
# IN   India         False
# RU  Russia          True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Comparison of booleans
print(True == False)

# Comparison of integers
print(-5 * 15 != 75)

# Comparison of strings
print("pyscript" == "PyScript")

# Compare a boolean with a numeric
print(True == 1)
# Out:
# False
# True
# False
# True

# %%
#Greater than or less than 
# Comparison of integers
x = -3 * 6
print(x >= -10)

# Comparison of strings
y = "test"
print("test" <= y)

# Comparison of booleans
print(True > False)
# Out:
# False
# True
# True

# %%
#Compare Arrays 
# Create arrays
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than or equal to 18
print(my_house >= 18)

# my_house less than your_house
print(my_house < your_house)
# Out:
# [ True  True False False]
# [False  True  True False]

# %%
#Boolean Operators

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Last slide above is the array equivalent of AND NOT OR

# %% [markdown]
# if, elif, else

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#The simplest if condition 
z = 5 
if z % 2  != 0 :
  print("z is an odd no")
# Out:
# z is an odd no

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Define variables
room = "bed"
area = 14.0

# if-elif-else construct for room
if room == "kit" :
    print("looking around in the kitchen.")
elif room == "bed":
    print("looking around in the bedroom.")
else :
    print("looking around elsewhere.")

# if-elif-else construct for area
if area > 15 :
    print("big place!")
else :
    print("pretty small.")
# Out:
# looking around in the bedroom.
# pretty small.

# %%
import pandas as pd 
# !wget -O Boston.csv https://www.dropbox.com/s/fm7xyvrjlopq9jk/Boston.csv?dl=0

boston = pd.read_csv('Boston.csv')

# %%
bst= boston

# %%
bst.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
huge=bst['AGE']= 65.2

# %%
#SUSET huge dataset only 
#non in 
bst01=bst["huge"]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Loops

# %%
#the while loop syntax 

error = 100.0 

while error > 1 :
 error = error/2
 print("now the error is"+"  "+str(error))
# Out:
# now the error is  50.0
# now the error is  25.0
# now the error is  12.5
# now the error is  6.25
# now the error is  3.125
# now the error is  1.5625
# now the error is  0.78125

# %%
#another example 

x = 1
while x < 4 :
    print(x)
    x = x + 1
# Out:
# 1
# 2
# 3

# %%
# Initialize offset
offset = 8

# Code the while loop
while offset != 0 :
    print("correcting...")
    offset = offset - 1
    print(offset)
# Out:
# correcting...
# 7
# correcting...
# 6
# correcting...
# 5
# correcting...
# 4
# correcting...
# 3
# correcting...
# 2
# correcting...
# 1
# correcting...
# 0

# %%
#An if inside a while loop 
# Initialize offset
offset = -6

# Code the while loop
while offset != 0 :
    print("correcting...")
    if offset > 0 :
      offset = offset-1 
    else : 
      offset = offset+1    
    print(offset)
# Out:
# correcting...
# -5
# correcting...
# -4
# correcting...
# -3
# correcting...
# -2
# correcting...
# -1
# correcting...
# 0

# %%
#For loop

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
fam = [1.73,0.75,0.89,1.99,0.64]

#Suppose you wanted to print the elements one by one 

for a in fam : 
  print(a)
# Out:
# 1.73
# 0.75
# 0.89
# 1.99
# 0.64

# %%
#note that here a is as arbitary word and can be replaced with aything

# %%
#you can use enumarate to higlight the index

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for index , a in enumerate(fam) : 
  print('Index '+str(index)+':'+str(a))
# Out:
# Index 0:1.73
# Index 1:0.75
# Index 2:0.89
# Index 3:1.99
# Index 4:0.64

# %%
for c in "family":
 print(c.capitalize())
# Out:
# F
# A
# M
# I
# L
# Y

# %%
# #another good example 
# Adapt the print() function in the for loop on the right so that the first printout becomes "room 1: 11.25", the second one "room 2: 18.0" and so on.

# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Adapt the printout
for index, area in enumerate(areas) :
    print("room " + str(index + 1) + ": " + str(area))
# Out:
# room 1: 11.25
# room 2: 18.0
# room 3: 20.0
# room 4: 10.75
# room 5: 9.5

# %%
#looping over list of lists 
# house list of lists
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]

# %%
# Build a for loop from scratch
for x,y in house : 
    print('the '+str(x)+' is '+str(y)+' sqm')
# Out:
# the hallway is 11.25 sqm
# the kitchen is 18.0 sqm
# the living room is 20.0 sqm
# the bedroom is 10.75 sqm
# the bathroom is 9.5 sqm

# %%
#looping over other data structures are also similar 
#but the way you define the sequence over which you are iterating will differ depending on the data structure

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
world={'afganisthan':30.55,'albania':2.77,'algeria':39.21,'USA':78.01,'Japan':15.06,'West_Indies':56.21}

# %%
for k , v in world.items() : 
  print(k+"  __  "+str(v))
# Out:
# afganisthan  __  30.55
# albania  __  2.77
# algeria  __  39.21
# USA  __  78.01
# Japan  __  15.06
# West_Indies  __  56.21

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw', 'austria':'vienna' }
          
# Iterate over europe
for a,b in europe.items() :
    print("the capital of "+str(a)+" is "+str(b))
# Out:
# the capital of spain is madrid
# the capital of france is paris
# the capital of germany is berlin
# the capital of norway is oslo
# the capital of italy is rome
# the capital of poland is warsaw
# the capital of austria is vienna

# %% [markdown]
# #Looping over a pandas df and adding a column
# ![image.png](data:image/png;base64,...)

# %%
#cars is createed above 
cars.head()
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200

# %%
for a,b in cars.iterrows():
  cars.loc[a,'countrylen']=len(b['country'])
cars.head()
# Out:
#          country  drives_right  cars_per_cap  countrylen
# 0  United States          True           809          13
# 1      Australia         False           731           9
# 2          Japan         False           588           5
# 3          India         False            18           5
# 4         Russia          True           200           6

# %% [markdown]
# ### A better method for larger datasets less time consuming
# using apply
# ![image.png](data:image/png;base64,...)

# %%
cars['countrylen02']=cars['country'].apply(len)
cars.head()
# Out:
#          country  drives_right  cars_per_cap  countrylen  countrylen02
# 0  United States          True           809          13            13
# 1      Australia         False           731           9             9
# 2          Japan         False           588           5             5
# 3          India         False            18           5             5
# 4         Russia          True           200           6             6

# %% [markdown]
# ### Hacker statistics

# %%
# Import numpy as np
import numpy as np

# Set the seed
np.random.seed(123)

# Generate and print random float
print(np.random.rand())
# Out:
# 0.6964691855978616

# %%
# Import numpy and set seed
import numpy as np
np.random.seed(123)

# Use randint() to simulate a dice
print(np.random.randint(1,7))

# Use randint() again
print(np.random.randint(1,7))
# Out:
# 6
# 3

# %%
# Numpy is imported, seed is set above 

# Starting step
step = 50

# Roll the dice
dice = np.random.randint(1,7)

# Finish the control construct
if dice <= 2 :
    step = step - 1
elif dice <=5 :
    step = step+1
else :
    step = step + np.random.randint(1,7)

# Print out dice and step
print(dice)
print(step)
# Out:
# 5
# 51

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#simulate a coin toss 
outcomes = []

for x in range(20) : 
  coin = np.random.randint(0,2)
  if coin == 0 :
      outcomes.append('heads')
  else :
    outcomes.append('tails')

# %%
print(outcomes)
# Out:
# ['tails', 'heads', 'tails', 'tails', 'heads', 'heads', 'heads', 'tails', 'tails', 'tails', 'heads', 'tails', 'heads', 'heads', 'heads', 'heads', 'tails', 'tails', 'tails', 'heads']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# you can turn this into a random walk by turning counting the total no of heads while simulating the game 
np.random.seed(123)
tails = [0]

for x in range(10) : 
  coin = np.random.randint(0,2)
  tails.append(tails[x]+coin)

print(tails)
# Out:
# [0, 0, 1, 1, 1, 1, 1, 1, 2, 3, 3]

# %%
#Back to the walk example 
# Numpy is imported, seed is set

# Initialize random_walk
random_walk=[0]

# Complete the ___
for x in range(100) :
    # Set step: last element in random_walk
   
    step=random_walk[-1]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        step = step - 1
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# Print random_walk
print(random_walk)
# Out:
# [0, 2, 3, 4, 9, 8, 9, 10, 11, 12, 13, 12, 17, 18, 19, 20, 19, 18, 17, 16, 15, 16, 17, 18, 24, 23, 22, 21, 22, 23, 24, 23, 24, 25, 24, 29, 30, 29, 28, 27, 26, 27, 26, 25, 27, 28, 31, 32, 34, 35, 36, 37, 36, 35, 36, 37, 38, 39, 38, 39, 40, 41, 44, 45, 46, 45, 46, 45, 46, 47, 48, 52, 51, 50, 51, 52, 53, 52, 53, 52, 53, 55, 60, 59, 60, 61, 62, 63, 64, 65, 64, 65, 66, 67, 69, 71, 70, 71, 72, 75, 74]

# %%
# Numpy is imported, seed is set

# Initialization
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt 

# Plot random_walk
plt.plot(random_walk)

# Show the plot
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt 
import numpy as np

np.random.seed(123)
final_tails = []

for a in range(1000000):
  tails =[0]
  for a in range(10):
    coin =np.random.randint(0,2)
    tails.append(tails[a] + coin)
  final_tails.append(tails[-1])
plt.hist(final_tails,bins=10)
plt.show()

# %%
# numpy and matplotlib imported, seed set.

# initialize and populate all_walks
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_aw =np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %%
#We still havent implimented clumsyness ('falling down the stairs bit')
# numpy and matplotlib imported, seed set

# Simulate random walk 250 times
all_walks = []
for i in range(250) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand() <= 0.001 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()

# %%
#Plotting the distribution 

# numpy and matplotlib imported, seed set

# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))

# Select last row from np_aw_t: ends
ends = np_aw_t[-1,:]

# Plot histogram of ends, display plot
plt.hist(ends)
plt.show()

# %%
#fraction of time you ended higher than 30 
np.mean(ends > 30)
# Out:
# 0.968

# %%
#fraction of time you ended higher than 70 
np.mean(ends > 70)
# Out:
# 0.566
