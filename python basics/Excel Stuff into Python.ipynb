# %%
#Preliminiary Code Chunks 

# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
##Code bit to mount drive
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Authenticate and create the PyDrive client.
# Notes : need to automate this step 
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link = 'https://drive.google.com/file/d/18oLmB7zhITuw6wd9kql53J_GaC299AwY/view?usp=sharing'
id = link.split("/")[5]
import pandas as pd 
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('df.csv')  
df = pd.read_csv('df.csv')

# %%
#https://stackabuse.com/converting-strings-to-datetime-in-python/
#Read the stack abuse & work through all the given examples 
#https://datatofish.com/strings-to-datetime-pandas/
##https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587

# %% [markdown]
# #Converting a string to a date

# %%
import pandas as pd

values = {'dates':  ['20190902','20190913','20190921'],
          'status': ['Opened','Opened','Closed']
          }

df = pd.DataFrame(values, columns = ['dates','status'])

print (df)
print (df.dtypes)
# Out:
#       dates  status
# 0  20190902  Opened
# 1  20190913  Opened
# 2  20190921  Closed
# dates     object
# status    object
# dtype: object

# %%
#Worked !!!!!!!

df['dates']= pd.to_datetime(df['dates'])

# %%
print (df.dtypes)
# Out:
# dates     datetime64[ns]
# status            object
# dtype: object

# %%
#DATED DIFF CALUTATION IN PYTHON ??

# %% [markdown]
# #String Function Equivalents

# %%
#https://medium.com/analytics-vidhya/common-excel-formulas-in-python-c5a7ce0ae07a

# %%
#01 String split 
link = 'https://drive.google.com/file/d/18oLmB7zhITuw6wd9kql53J_GaC299AwY/view?usp=sharing'
id = link.split("/")[5]

# %%
#Check 
id
# Out:
# '18oLmB7zhITuw6wd9kql53J_GaC299AwY'

# %%
##Uppercase & Lowercase

# %%
df.head(1)
# Out:
#   Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 0           WN          7/1/2015  ...                                    0 NaN
#
# [1 rows x 18 columns]

# %%
#lowercase 
df['Carrier Code']=df['Carrier Code'].str.lower()

# %%
#Check 
df.head(1)
# Out:
#   Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 0           wn          7/1/2015  ...                                    0 NaN
#
# [1 rows x 18 columns]

# %%
#Uppercase 
df['Carrier Code']=df['Carrier Code'].str.upper()

# %%
#Check 
df.head(1)
# Out:
#   Carrier Code Date (MM/DD/YYYY)  ...  DelayLate Aircraft Arrival(Minutes) F18
# 0           WN          7/1/2015  ...                                    0 NaN
#
# [1 rows x 18 columns]

# %%
#Calculate Len  and add the same as a new Column 
df['LengthofTail']=df['Tail Number'].str.len()

# %%
#Check 
df.head(1)
# Out:
#   Carrier Code Date (MM/DD/YYYY)  ...  Carrier Code01 LengthofTail
# 0           WN          7/1/2015  ...               6            6
#
# [1 rows x 20 columns]

# %%
#Left
dflft=df['Tail Number'].str[:2]
dflft.head()
# Out:
# 0    N8
# 1    N8
# 2    N6
# 3    N2
# 4    N2
# Name: Tail Number, dtype: object

# %%
#Right 
dflft=df['Tail Number'].str[:-2]
dflft.head()
# Out:
# 0    N860
# 1    N860
# 2    N646
# 3    N204
# 4    N233
# Name: Tail Number, dtype: object

# %%
#Mid
df['Tail Number'].str[4:6]
# Out:
# 0       7M
# 1       9A
# 2       SW
# 3       WN
# 4       LV
#         ..
# 1735    1C
# 1736    SW
# 1737    WN
# 1738    7A
# 1739    WN
# Name: Tail Number, Length: 1740, dtype: object

# %%
#Find #Contains #Like
#Link:https://stackoverflow.com/questions/4666973/how-to-extract-the-substring-between-two-markers

# %% [markdown]
# *regular expression*
#
#
# **import re**
#
# **re.search(r"(?<=AAA).*?(?=ZZZ)", your_text).group(0)**
#
#
# The above as-is will fail with an AttributeError if there are no "AAA" and "ZZZ" in your_text
#
# *string methods*
#
# **your_text.partition("AAA")[2].partition("ZZZ")[0]**
#
#
# The above will return an empty string if either "AAA" or "ZZZ" don't exist in your_text.
#
#
#
#
#
# https://docs.python.org/3/library/re.html
#
#
#
# https://www.youtube.com/watch?v=K8L6KVGG-7o
#
#
#
#
# https://www.youtube.com/watch?v=zN8rwVXwRUE

# %%
#Break this down find the pattern 

import re
re.findall(r'\d{1,5}','gfgfdAAA1234ZZZuijjk')
# Out:
# ['1234']

# %%
#Concatenate 
x = 'gfgfdAAA1234ZZZuijjk'
x.split('AAA')[1].split('ZZZ')[0]
# Out:
# '1234'
