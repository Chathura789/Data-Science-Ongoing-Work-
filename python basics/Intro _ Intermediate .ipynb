# %% [markdown]
# Basic Maths -->

# %%
## How much is your $100 worth after 7 years?
100*(1.07**7)
# Out:
# 160.57814764784305

# %%
2**7
# Out:
# 128

# %% [markdown]
# Variables and Types

# %%
a=True
b= "Hello"
c = 78945

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# str

# %%
type(c)
# Out:
# int

# %%
#operations with types 
# Several variables to experiment with
savings = 100
factor = 1.1
desc = "compound interest"

# Assign product of factor and savings to year1
year1=factor*savings

# Print the type of year1
print(type(year1))

# Assign sum of desc and desc to doubledesc
doubledesc=desc+desc 

# Print out doubledesc
print(doubledesc)
# Out:
# <class 'float'>
# compound interestcompound interest

# %%
#Type conversions 
# Definition of savings and result
savings = 100
result = 100 * 1.10 ** 7

# Fix the printout
print("I started with $" + str(savings) + " and now have $" + str(result) + ". Awesome!")

# Definition of pi_string
pi_string = "3.1415926"

# Convert pi_string into float: pi_float
pi_float=float(pi_string)

# %%
#Lists

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np 
x = np.array([[1, 2, 7],
              [7, 7, 1]])
y = np.array([[6, 5, 5], 
              [0, 6, 1]])

# %%
print(x - y)
# Out:
# [[-5 -3  2]
#  [ 7  1  0]]

# %%
p = [0, 5, 15, 5, 10, 8]
print(sorted(p, reverse=False))
# Out:
# [0, 5, 5, 8, 10, 15]

# %% [markdown]
# # Intermediate

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.show()

# %%
# Scatter plot
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c = col, alpha = 0.8)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Additional customizations
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')

# Add grid() call
plt.grid(True)

# Show the plot
plt.show()

# %%
#example to show that lists are not convinient 

# Definition of countries and capital
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

# Get index of 'germany': ind_ger
ind_ger = countries.index('germany')

# Use ind_ger to print out capital of Germany
print(capitals[ind_ger])

# %%
#Basic dictionary europe 
europe={'spain':'madrid', 'france':'paris', 'germany': 'berlin', 'norway':'oslo'}

# Print europe
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo'}

# %%
# Print out the keys in europe
print(europe.keys())

# Print out value that belongs to key 'norway'
print (europe['norway'])
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])
# oslo

# %%
# adding a value into a dictionary
europe['sealand'] = 'timbuktoo'

# %%
europe
# Out:
# {'france': 'paris',
#  'germany': 'berlin',
#  'norway': 'oslo',
#  'sealand': 'timbuktoo',
#  'spain': 'madrid'}

# %%
#Checking if a value is in a dictionary 

'sealand' in europe
# Out:
# True

# %%
#delete an item from a python dictionary 
del[europe['sealand']]

# %%
europe
# Out:
# {'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'spain': 'madrid'}

# %%
#there can be dictionaries of dictionaries 
# Dictionary of dictionaries
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }
           
           
# Print out the capital of France
print(europe['france']['capital'])

# Create sub-dictionary data
data={ 'capital':'rome', 'population':59.83 }

# Add data to europe under key 'italy'
europe['italy']=data

# Print europe
print(europe)

# %% [markdown]
# #Pandas basics

# %%
# pandas dataframe from dictionary 

import pandas as pd

# Build cars DataFrame
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
dict = { 'country':names, 'drives_right':dr, 'cars_per_cap':cpc }
cars = pd.DataFrame(dict)
print(cars)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45

# %%
#row label modification of a pandas DF 
# Definition of row_labels
row_labels = ['US', 'AUS', 'JAP', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index=row_labels

# Print cars again
print(cars)
# Out:
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JAP          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %%
#Pandas DF from a CSV 

import pandas as pd 
# !wget -O Boston.csv https://www.dropbox.com/s/fm7xyvrjlopq9jk/Boston.csv?dl=0

bst = pd.read_csv('Boston.csv')
# Out:
# --2021-04-19 10:27:54--  https://www.dropbox.com/s/fm7xyvrjlopq9jk/Boston.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.82.18, 2620:100:6032:18::a27d:5212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.82.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/fm7xyvrjlopq9jk/Boston.csv [following]
# --2021-04-19 10:27:54--  https://www.dropbox.com/s/raw/fm7xyvrjlopq9jk/Boston.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucfde50006edb6977cd5552112f6.dl.dropboxusercontent.com/cd/0/inline/BM5HWFtQFbzVq-Wi6JD7x5zZ9kouFuH6uKXbePP-btzmNnzhg1ZrDGTABsQoDMleBuaQoY0O-c4Y6ov50AXv3ekqcI29lZRPYhujKRoaF9qsOxiYTi51Xkma2S6hVWvjcnlxUurxdl_Khsv6E7MPRaNC/file# [following]
# ...

# %%
bst.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# if the first coulumn contains the row indexes
# ![image.png](data:image/png;base64,...)

# %%
#this returns a pandas series 
d1 = bst['ZN']
type(d1)
# Out:
# pandas.core.series.Series

# %%
#if you want a dataframe 

d2 = bst[['ZN','AGE']]
type(d2)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd 
# !wget -O orders.csv https://www.dropbox.com/s/e3qbyxhx7wzc9wk/Sample%20-%20Superstore_Orders.csv?dl=0

ord = pd.read_csv('orders.csv',index_col= 6)
# Out:
# --2021-04-19 10:27:55--  https://www.dropbox.com/s/e3qbyxhx7wzc9wk/Sample%20-%20Superstore_Orders.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6032:18::a27d:5212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/e3qbyxhx7wzc9wk/Sample%20-%20Superstore_Orders.csv [following]
# --2021-04-19 10:27:56--  https://www.dropbox.com/s/raw/e3qbyxhx7wzc9wk/Sample%20-%20Superstore_Orders.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc5681f599b44a085b5f467910c1.dl.dropboxusercontent.com/cd/0/inline/BM7GWPBVd1khOT7xEB17d4m1f1Dm2ZFsstX4oAzDtP5Iu1n3C6UUDDrWRdhb_dy5icm_oGePTg0Y0d6bXua_JuUm89UNkggMIrywgJdzFBSYh8Ja3jzRo9NCqIY2bOJVISZ_p9vgIuynNtoEITQ_J6PR/file# [following]
# ...

# %%
orders.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-13d9bc03b671> in <module>()
# ----> 1 orders.head(2)
#
# NameError: name 'orders' is not defined

# %%
#loc iloc pandas 
#loc is label based 
#iloc is integer based 


O1 =orders.loc['CA-2019-152156':'CA-2019-138688']
type(O1)

# %%
O2 =orders.loc[['CA-2019-152156','CA-2019-138688']]
type(O2)

# %%
#Return a selection of rows & columns  
o3 =orders.loc[['CA-2019-152156','CA-2019-138688'],['Manufacturer','Region']]

# %%
type(o3)

# %%
#This time the intersection spans all rows only select columns 
o4 =orders.loc[:,['Manufacturer','Region']]
type(o4)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#iloc function 

O1 =orders.iloc[1:5]
type(O1)

# %%
O1.head(3)

# %%
#SELECT only needed rows & columns with 
o3 =orders.iloc[[1,2,3],[2,5]]
o3.head(3)

# %%
o4 =orders.iloc[:,[2,5]]
o4.head(3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Simple if expression 
x = 8
if x%2 == 0 : 
  print('x is even')

# %%
''' To exit the if statement, simply continue with some Python code without indentation, and Python will now that it's not part of the if statement.'''

# %%
x = 5 
if x%2 == 0 :
  print('x is even')
else : 
  print('x is not even')

# %%
x = 0 
if x%2 == 0 and x != 0 :
  print('x is even')
elif x==0 :
  print('x is zero')


else : 

  print('x is not even')

# %%
#filtering PANDAS Dataframes 

o1 = ord[ord['Region']=='East']
o1.head(4)

# %%
import numpy as np 

o1 = ord[ np.logical_and(ord['Region']=='South',ord['Quantity']>=2) ]
o1.head(3)

# %%
o1 = ord[ np.logical_and(ord['Region']=='South',ord['Quantity']<=3) ]
o1.head(5)

# %% [markdown]
# ##Loops

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
error = 100
while error>0.01 : 
  error = error/4 
  print('now the error is'+' '+str(error))

# %%
# Initialize offset
offset = 8

# Code the while loop
while offset != 0 :
    print( "correcting...")
    offset= offset -1
    print(offset)

# %%
#While loop with if 
# Initialize offset
offset = -6

# Code the while loop
while offset != 0 :
    print("correcting...")
    if offset > 0 :
        offset = offset  -1 
    else :    
        offset = offset + 1
    print(offset)

# %%
fam = [1.25,2.25,3.25,4.25,6.25,8.59,9.78]

for i in fam :
  print(i)

# %%
#enuimerate and print the index also 

for index, i in enumerate(fam):
  print('index is   '+str(index)+'    and the value is   '+str(i) )

# %%
longest_word ='rindfleischetikettierungsüberwachungsaufgabenübertragungsgesetz'

for i in longest_word : 
  print(i.capitalize())

# %% [markdown]
# # Looping over items in a dictionary  or numpy arrays

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png]()
#
# pay attention dictionaries require a method
# nmpy array require a function

# %%
world =  {
    
    'usa'  : 10.25,
    'canada': 7.25,
    'brazil' : 5.89,
    'china' : 9.87



}

# %%
#looping over a dictionary 
for a,b in world.items():
   print('for '+ str(a) +'    its      '+ str(b))
# Out:
# for usa    its      10.25
# for canada    its      7.25
# for brazil    its      5.89
# for china    its      9.87

# %%
np_height = np.array([1.25,2.36,5.36,4.12,2.01,8.57,9.45])
np_weight = np.array([65.4,60.0,54.2,56.5,85.4,74.2,80.2])

meas = np.array([np_height,np_weight])

# %%
for i in np.nditer(meas):
  print(i)
# Out:
# 1.25
# 2.36
# 5.36
# 4.12
# 2.01
# 8.57
# 9.45
# 65.4
# 60.0
# 54.2
# 56.5
# 85.4
# 74.2
# 80.2

# %% [markdown]
# #Looping over a Data frame

# %%
for i in ord:
  print(i)
# Out:
# Category
# City
# Country/Region
# Customer Name
# Manufacturer
# Order Date
# Postal Code
# Product Name
# Region
# Segment
# Ship Date
# Ship Mode
# State
# Sub-Category
# Discount
# Profit
# Quantity
# Sales

# %%
#As above if you just straight up loop over a a data frame you get the column names

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Adfding a column into a data frame

for i, j in ord.iterrows():
  ord.loc[i,'name_length'] = len(j['Manufacturer'])

# %%
ord.head(4)
# Out:
#                        Category             City  ...     Sales name_length
# Order ID                                          ...
# CA-2019-152156        Furniture        Henderson  ...  261.9600         3.0
# CA-2019-152156        Furniture        Henderson  ...  731.9400         3.0
# CA-2019-138688  Office Supplies      Los Angeles  ...   14.6200         9.0
# US-2018-108966        Furniture  Fort Lauderdale  ...  957.5775         5.0
#
# [4 rows x 19 columns]

# %%
# A MUCH MORE SUCCINT  WAY TO DO THE ABOVE 
#USING APPLY

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ord['name_length']=ord['Product Name'].apply(len)
ord.head(3)
# Out:
#                        Category         City  ... name_length name_length001
# Order ID                                      ...
# CA-2019-152156        Furniture    Henderson  ...          33             33
# CA-2019-152156        Furniture    Henderson  ...          59             59
# CA-2019-138688  Office Supplies  Los Angeles  ...          57             57
#
# [3 rows x 20 columns]

# %% [markdown]
# # Pandas Basics

# %%
# !pip install -U pandas
import pandas as pd
# Out:
# ...
#      |████████████████████████████████| 9.9MB 4.0MB/s
# ...
# ERROR: google-colab 1.0.0 has requirement pandas~=1.1.0; python_version >= "3.0", but you'll have pandas 1.2.4 which is incompatible.
# ...
#   Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ...

# %%
# .head() returns the first few rows (the “head” of the DataFrame).
# .info() shows information on each of the columns, such as the data type and number of missing values.
ord.info()
# .shape returns the number of rows and columns of the DataFrame.
# .describe() calculates a few summary statistics for each column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, CA-2019-152156 to CA-2020-119914
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        9994 non-null   object
#  1   City            9994 non-null   object
#  2   Country/Region  9994 non-null   object
#  3   Customer Name   9994 non-null   object
#  4   Manufacturer    9994 non-null   object
#  5   Order Date      9994 non-null   object
#  6   Postal Code     9983 non-null   float64
#  7   Product Name    9994 non-null   object
#  8   Region          9994 non-null   object
#  9   Segment         9994 non-null   object
#  10  Ship Date       9994 non-null   object
#  11  Ship Mode       9994 non-null   object
#  12  State           9994 non-null   object
#  13  Sub-Category    9994 non-null   object
#  14  Discount        9994 non-null   float64
#  15  Profit          9994 non-null   float64
# ...

# %%
# .values: A two-dimensional NumPy array of values.
# .columns: An index of columns: the column names.
# .index: An index for the rows: either row numbers or row names.

# %%
#sorting values in this example by profit 
o4 = ord.sort_values("Profit",ascending=False)

# %%
o4.head()
# Out:
#                        Category         City  ... Quantity     Sales
# Order ID                                      ...
# CA-2019-118689       Technology    Lafayette  ...        5  17499.95
# CA-2020-140151       Technology      Seattle  ...        4  13999.96
# CA-2020-166709       Technology       Newark  ...        3  10499.97
# CA-2019-117121  Office Supplies      Detroit  ...       13   9892.74
# CA-2017-116904  Office Supplies  Minneapolis  ...        5   9449.95
#
# [5 rows x 18 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
o5 = ord[(ord["Profit"]>5000) & (ord["Manufacturer"] =='Canon') ]
o5.head(3)
# Out:
#                   Category       City  ... Quantity     Sales
# Order ID                               ...
# CA-2020-166709  Technology     Newark  ...        3  10499.97
# CA-2019-118689  Technology  Lafayette  ...        5  17499.95
# CA-2020-140151  Technology    Seattle  ...        4  13999.96
#
# [3 rows x 18 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
o5 = ord[(ord["Profit"]>5000) & (ord["Manufacturer"] .isin(['Canon','GBC'])) ]
o5.head()
# Out:
#                   Category       City  ... Quantity     Sales
# Order ID                               ...
# CA-2020-166709  Technology     Newark  ...        3  10499.97
# CA-2019-118689  Technology  Lafayette  ...        5  17499.95
# CA-2020-140151  Technology    Seattle  ...        4  13999.96
#
# [3 rows x 18 columns]

# %% [markdown]
# #Type conversion
# #especially dates

# %%
#Type conversion 
#esepecially dates 
ord['Ship Date']= pd.to_datetime(ord['Ship Date'])
ord['Order Date']= pd.to_datetime(ord['Order Date'])

ord.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d55899ad6ff2> in <module>()
#       1 #Type conversion
#       2 #esepecially dates
# ----> 3 ord['Ship Date']= pd.to_datetime(ord['Ship Date'])
#       4 ord['Order Date']= pd.to_datetime(ord['Order Date'])
#       5
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
""""
# Sort homelessness by region, then descending family members
homelessness_reg_fam = homelessness.sort_values(['region','family_members'],ascending=[True,False])

# Print the top few rows
print(homelessness_reg_fam.head())


"""

# %%
o5 = ord[ord["Profit"]>5000 ]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# https://note.nkmk.me/en/python-pandas-len-shape-size/
o6 = ord.drop_duplicates(subset=['Manufacturer','Product Name'])
o6.shape
# Out:
# (1849, 18)

# %%
ord['Manufacturer'].value_counts(sort=True).head(2)
# Out:
# Other    1893
# Xerox     859
# Name: Manufacturer, dtype: int64

# %%
ord.groupby('Manufacturer')['Sales'].mean()
# Out:
# Manufacturer
# 3-ring staple pack       7.018667
# 3D Systems            4159.968000
# 3M                     109.047586
# ACCOHIDE                10.241600
# AT&T                   266.471800
#                          ...
# Xerox                   66.990075
# Xerox 1971              18.974667
# XtraLife                30.599733
# Zebra                 1129.807750
# iOttie                  62.825714
# Name: Sales, Length: 183, dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ord.groupby(['Manufacturer'])['Sales'].count().nlargest(10)
# Out:
# Manufacturer
# Other       1893
# Xerox        859
# Avery        557
# GBC          332
# Global       291
# Newell       276
# Eldon        245
# Fellowes     230
# Logitech     217
# Acco         214
# Name: Sales, dtype: int64

# %% [markdown]
# #Indexing

# %%
# !wget -O temperatures.csv https://www.dropbox.com/s/ecbzmrmbr375ijt/temperatures.csv?dl=0
# Out:
# --2021-04-19 10:27:38--  https://www.dropbox.com/s/ecbzmrmbr375ijt/temperatures.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6032:18::a27d:5212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/ecbzmrmbr375ijt/temperatures.csv [following]
# --2021-04-19 10:27:39--  https://www.dropbox.com/s/raw/ecbzmrmbr375ijt/temperatures.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc65c195ff2d568e445af82bfddd.dl.dropboxusercontent.com/cd/0/inline/BM53bo1NPV6K3MmEV3qnTRTOmVxHzl-ejfesxHQDEID7keuXvr5m2es8m5OKNxwk0dPvf4IZf3f5gQfJDPt2X3cAExtSalH-qbMkP5WaZefj6Ic9YFMrYXvKvHO7MzeMHihuZlmsKUC_hydFTjrL1yD7/file# [following]
# ...

# %%
temperatures = pd.read_csv('temperatures.csv')
temperatures['date']= pd.to_datetime(temperatures['date'])

# %%
temperatures.head(3)
# Out:
#        date     city        country  avg_temp_c
# 0  1/1/2000  Abidjan  Côte D'Ivoire      27.293
# 1  2/1/2000  Abidjan  Côte D'Ivoire      27.685
# 2  3/1/2000  Abidjan  Côte D'Ivoire      29.061

# %%
temperatures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16500 entries, 0 to 16499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        16500 non-null  datetime64[ns]
#  1   city        16500 non-null  object
#  2   country     16500 non-null  object
#  3   avg_temp_c  16407 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 515.8+ KB

# %%
temperatures.describe()
# Out:
#          avg_temp_c
# count  16407.000000
# mean      19.732877
# std        9.579635
# min      -23.495000
# 25%       14.870000
# 50%       22.119000
# 75%       27.001500
# max       38.283000

# %%
# Make a list of cities to subset on
cities = ["Moscow", "Saint Petersburg"]

# Subset temperatures using square brackets
print(temperatures[temperatures["city"].isin(cities)])

# Subset temperatures_ind using .loc[]
print(temperatures_ind.loc[cities])

# %%
temperatures_ind = temperatures.set_index(['country','city'])


# Sort temperatures_ind by index values
print(temperatures_ind.sort_index())

# Sort temperatures_ind by index values at the city level
print(temperatures_ind.sort_index(level="city"))

# Sort temperatures_ind by country then descending city
print(temperatures_ind.sort_index(level=["country", "city"], ascending = [True, False]))
# Out:
#                         date  avg_temp_c
# country     city
# Afghanistan Kabul   1/1/2000       3.326
#             Kabul   2/1/2000       3.454
#             Kabul   3/1/2000       9.612
#             Kabul   4/1/2000      17.925
#             Kabul   5/1/2000      24.658
# ...                      ...         ...
# Zimbabwe    Harare  5/1/2013      18.298
#             Harare  6/1/2013      17.020
#             Harare  7/1/2013      16.299
#             Harare  8/1/2013      19.232
#             Harare  9/1/2013         NaN
#
# [16500 rows x 2 columns]
#                            date  avg_temp_c
# country       city
# Côte D'Ivoire Abidjan  1/1/2000      27.293
#               Abidjan  2/1/2000      27.685
#               Abidjan  3/1/2000      29.061
#               Abidjan  4/1/2000      28.162
#               Abidjan  5/1/2000      27.547
# ...                         ...         ...
# China         Xian     5/1/2013      18.979
#               Xian     6/1/2013      23.522
# ...

# %%
# Use Boolean conditions to subset temperatures for rows in 2010 and 2011
temperatures_bool = temperatures[(temperatures["date"] >= "2010-01-01") & (temperatures["date"] <= "2011-12-31")]
print(temperatures_bool)

# Set date as an index and sort the index
temperatures_ind = temperatures.set_index("date").sort_index()

# Use .loc[] to subset temperatures_ind for rows in 2010 and 2011
print(temperatures_ind.loc["2010":"2011"])

# Use .loc[] to subset temperatures_ind for rows from Aug 2010 to Feb 2011
print(temperatures_ind.loc["2010-08":"2011-02"])
# Out:
# Empty DataFrame
# Columns: [date, city, country, avg_temp_c]
# Index: []
# Empty DataFrame
# Columns: [city, country, avg_temp_c]
# Index: []
# Empty DataFrame
# Columns: [city, country, avg_temp_c]
# Index: []

# %% [markdown]
# #Pivot tables

# %%
# Add a year column to temperatures
temperatures["year"] = temperatures["date"].dt.year

# Pivot avg_temp_c by country and city vs year
temp_by_country_city_vs_year = temperatures.pivot_table("avg_temp_c", index = ["country", "city"], columns = "year")

# See the result
print(temp_by_country_city_vs_year)
# Out:
# year                                 2000       2001  ...       2012       2013
# country       city                                    ...
# Afghanistan   Kabul             15.822667  15.847917  ...  14.510333  16.206125
# Angola        Luanda            24.410333  24.427083  ...  24.240083  24.553875
# Australia     Melbourne         14.320083  14.180000  ...  14.268667  14.741500
#               Sydney            17.567417  17.854500  ...  17.474333  18.089750
# Bangladesh    Dhaka             25.905250  25.931250  ...  26.283583  26.587000
# ...                                   ...        ...  ...        ...        ...
# United States Chicago           11.089667  11.703083  ...  12.821250  11.586889
#               Los Angeles       16.643333  16.466250  ...  17.089583  18.120667
#               New York           9.969083  10.931000  ...  11.971500  12.163889
# Vietnam       Ho Chi Minh City  27.588917  27.831750  ...  28.248750  28.455000
# ...

# %%
type(temp_by_country_city_vs_year)
# Out:
# pandas.core.frame.DataFrame

# %%
# Subset for Egypt to India
temp_by_country_city_vs_year.loc["Egypt":"India"]

# Subset for Egypt, Cairo to India, Delhi
temp_by_country_city_vs_year.loc[("Egypt", "Cairo"):("India", "Delhi")]

# Subset in both directions at once
temp_by_country_city_vs_year.loc[("Egypt", "Cairo"):("India", "Delhi"), "2005":"2010"]
# Out:
# year                       2005       2006  ...       2009       2010
# country  city                               ...
# Egypt    Cairo        22.006500  22.050000  ...  22.625000  23.718250
#          Gizeh        22.006500  22.050000  ...  22.625000  23.718250
# Ethiopia Addis Abeba  18.312833  18.427083  ...  18.765333  18.298250
# France   Paris        11.552917  11.788500  ...  11.464083  10.409833
# Germany  Berlin        9.919083  10.545333  ...  10.062500   8.606833
# India    Ahmadabad    26.828083  27.282833  ...  28.095833  28.017833
#          Bangalore    25.476500  25.418250  ...  25.725750  25.705250
#          Bombay       27.035750  27.381500  ...  27.844500  27.765417
#          Calcutta     26.729167  26.986250  ...  27.153250  27.288833
#          Delhi        25.716083  26.365917  ...  26.554250  26.520250
#
# [10 rows x 6 columns]

# %%
# Get the worldwide mean temp by year
mean_temp_by_year = temp_by_country_city_vs_year.mean()

# Filter for the year that had the highest mean temp
print(mean_temp_by_year[mean_temp_by_year == mean_temp_by_year.max()])

# Get the mean temp by city
mean_temp_by_city = temp_by_country_city_vs_year.mean(axis="columns")

# Filter for the city that had the lowest mean temp
print(mean_temp_by_city[mean_temp_by_city == mean_temp_by_city.min()])
# Out:
# year
# 2013    20.312285
# dtype: float64
# country  city
# China    Harbin    4.876551
# dtype: float64

# %% [markdown]
# #Visualizing your data

# %%
link = 'https://www.dropbox.com/s/8bp0k0ijp0stwcy/avoplotto.pkl?dl=0'

# %%
# !wget -O avoplotto.pkl https://www.dropbox.com/s/8bp0k0ijp0stwcy/avoplotto.pkl?dl=0
# Out:
# --2021-04-19 16:01:40--  https://www.dropbox.com/s/8bp0k0ijp0stwcy/avoplotto.pkl?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.82.18, 2620:100:6032:18::a27d:5212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.82.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/8bp0k0ijp0stwcy/avoplotto.pkl [following]
# --2021-04-19 16:01:40--  https://www.dropbox.com/s/raw/8bp0k0ijp0stwcy/avoplotto.pkl
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc65c6f5f48692a957eb231b229c.dl.dropboxusercontent.com/cd/0/inline/BM6ZJEDtvBRYosIMaXcQJL43grYAgcIYqLdInyDIF-ghV5QkjMYt911T663l9TaVLno5z24EKm57VV8OWiIrCfuGs7QdwgH_E0sMJpdKT6f8ayGwGCseUu__rc28WGdGDXIVwa5CAWzZybIQGzfWu0GK/file# [following]
# ...

# %%
import pickle

with open('avoplotto.pkl', 'rb') as f:
    avocados = pickle.load(f)

# %%
type(avocados)
# Out:
# pandas.core.frame.DataFrame

# %%
avocados.head()
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %%
avocados['date']= pd.to_datetime(avocados['date'])

avocados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1014 non-null   datetime64[ns]
#  1   type       1014 non-null   object
#  2   year       1014 non-null   int64
#  3   avg_price  1014 non-null   float64
#  4   size       1014 non-null   object
#  5   nb_sold    1014 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 47.7+ KB

# %%
import matplotlib.pyplot as plt

# %%
# Get the total number of avocados sold of each size
nb_sold_by_size = avocados.groupby("size")["nb_sold"].sum()

# Create a bar plot of the number of avocados sold by size
nb_sold_by_size.plot(kind="bar")

# Show the plot
plt.show()

# %%
#Changes in Sales over time 
# Get the total number of avocados sold on each date
nb_sold_by_date = avocados.groupby("date")["nb_sold"].sum()

# Create a line plot of the number of avocados sold by date
nb_sold_by_date.plot(kind="line")

# Show the plot
plt.show()

# %%
# Scatter plot of nb_sold vs avg_price with title
avocados.plot(x="nb_sold", y="avg_price", kind="scatter", title="Number of avocados sold vs. average price")

# Show the plot
plt.show()

# %%
# Modify bins to 20
avocados[avocados["type"] == "conventional"]["avg_price"].hist(alpha=0.5, bins=20)
# Modify bins to 20
avocados[avocados["type"] == "organic"]["avg_price"].hist(alpha=0.5, bins=20)
# Add a legend
plt.legend(["conventional", "organic"])
# Show the plot
plt.show()

# %%
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

# Check individual values for missing values
print(avocados.isna())

# Check each column for missing values
print(avocados.isna().any())

# Bar plot of missing values by variable
avocados.isna().sum().plot(kind="bar")

# Show plot
plt.show()
# Out:
#        date   type   year  avg_price   size  nb_sold
# 0     False  False  False      False  False    False
# 1     False  False  False      False  False    False
# 2     False  False  False      False  False    False
# 3     False  False  False      False  False    False
# 4     False  False  False      False  False    False
# ...     ...    ...    ...        ...    ...      ...
# 1009  False  False  False      False  False    False
# 1010  False  False  False      False  False    False
# 1011  False  False  False      False  False    False
# 1012  False  False  False      False  False    False
# 1013  False  False  False      False  False    False
#
# [1014 rows x 6 columns]
# date         False
# type         False
# year         False
# avg_price    False
# size         False
# nb_sold      False
# dtype: bool

# %%
chars_to_remove = [\+,\,,\$]
# Out:
#   File "<ipython-input-46-b44dcc533fa0>", line 1
#     chars_to_remove = [\+,\,,\$]
#                                 ^
# SyntaxError: unexpected character after line continuation character
